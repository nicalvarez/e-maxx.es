# %%
import requests

# %%
>>> r = requests.get('https://api.github.com/events')

# %%
r.text
# Out:
# u'[{"id":"2484516989","type":"CreateEvent","actor":{"id":8398711,"login":"AsianAnarchy","gravatar_id":"","url":"https://api.github.com/users/AsianAnarchy","avatar_url":"https://avatars.githubusercontent.com/u/8398711?"},"repo":{"id":28542890,"name":"AsianAnarchy/AsianAnarchy.github.io","url":"https://api.github.com/repos/AsianAnarchy/AsianAnarchy.github.io"},"payload":{"ref":null,"ref_type":"repository","master_branch":"master","description":"","pusher_type":"user"},"public":true,"created_at":"2014-12-27T18:02:41Z"},{"id":"2484516988","type":"WatchEvent","actor":{"id":10323409,"login":"netdudeuk","gravatar_id":"","url":"https://api.github.com/users/netdudeuk","avatar_url":"https://avatars.githubusercontent.com/u/10323409?"},"repo":{"id":22769197,"name":"ToontownInfinite/launcher-win32","url":"https://api.github.com/repos/ToontownInfinite/launcher-win32"},"payload":{"action":"started"},"public":true,"created_at":"2014-12-27T18:02:41Z","org":{"id":8052171,"login":"ToontownInfinite","gr
# ...
